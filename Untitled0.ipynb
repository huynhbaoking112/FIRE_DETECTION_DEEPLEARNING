# %% [markdown]
# <a href="https://colab.research.google.com/github/huynhbaoking112/FIRE_DETECTION_DEEPLEARNING/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/drive/MyDrive/data/data.yaml epochs=50 imgsz=640
# Out:
# ...
# 100% 6.25M/6.25M [00:00<00:00, 157MB/s]
# Ultralytics 8.3.19 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
